# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('__file__').parent.resolve()))
from aem_csv_to_xyz import data_csv_to_xyz

# %%
# --- Configuration ---
csv_file    = '/path/to/your/input_data_file.csv'
output_file = None  # None = same directory and base name, .xyz extension

# %%
out = data_csv_to_xyz(csv_file, output_file)
print(f'Output: {out}')
